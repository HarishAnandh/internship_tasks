# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
col_list=["id","first_name","last_name","age","city","salary","joined"]
df = pd.read_csv("sample-simple.csv",usecols=col_list)
print(df)
# Out:
#    id first_name  last_name  age        city     salary      joined
# 0   1       Liam   Williams   49   Riverside  156973.24  2020-04-18
# 1   2       Jane   Williams   71    Fairview   50435.05  2024-01-27
# 2   3       Emma      Moore   76    Fairview  128705.61  2022-01-06
# 3   4       Emma   Martinez   43  Burlington  106198.11  2016-01-05
# 4   5   Benjamin  Rodriguez   62  Manchester  189641.05  2023-04-19
# 5   6     Amelia   Williams   34  Manchester   26628.09  2016-08-19
# 6   7        Mia      Jones   21     Ashland   33038.53  2021-01-03
# 7   8       Emma      Lopez   30  Greenville  146867.05  2015-12-15
# 8   9   Isabella      Lopez   29  Greenville  175981.13  2015-01-27
# 9  10     Amelia    Johnson   54     Madison   22669.84  2020-03-09

# %%
mean1 = df['salary'].mean()
print(mean1)
# Out:
# 103713.76999999999

# %%
sum1 =df['salary'].sum()
max1 =df['salary'].max()
min1 = df['salary'].min()
count1 = df['id'].count()
median1 = df['age'].median()
sd1 = df['salary'].std()
var1 = df['salary'].var()
print(sum1,max1,min1,count1,median1,sd1,var1)
# Out:
# 1037137.7 189641.05 22669.84 10 46.0 65217.19414185853 4253282411.7368665

# %%
import pandas as pd
col_list=["id","first_name","last_name","age","city","salary","joined"]
df = pd.read_csv("sample-simple.csv",usecols=col_list)
print(df)
# Out:
#    id first_name  last_name  age        city     salary      joined
# 0   1       Liam   Williams   49   Riverside  156973.24  2020-04-18
# 1   2       Jane   Williams   71    Fairview   50435.05  2024-01-27
# 2   3       Emma      Moore   76    Fairview  128705.61  2022-01-06
# 3   4       Emma   Martinez   43  Burlington  106198.11  2016-01-05
# 4   5   Benjamin  Rodriguez   62  Manchester  189641.05  2023-04-19
# 5   6     Amelia   Williams   34  Manchester   26628.09  2016-08-19
# 6   7        Mia      Jones   21     Ashland   33038.53  2021-01-03
# 7   8       Emma      Lopez   30  Greenville  146867.05  2015-12-15
# 8   9   Isabella      Lopez   29  Greenville  175981.13  2015-01-27
# 9  10     Amelia    Johnson   54     Madison   22669.84  2020-03-09

# %%
print(df.shape,"\n",df.head(5))
print(df.describe())
# Out:
# (10, 7)
#     id first_name  last_name  age        city     salary      joined
# 0   1       Liam   Williams   49   Riverside  156973.24  2020-04-18
# 1   2       Jane   Williams   71    Fairview   50435.05  2024-01-27
# 2   3       Emma      Moore   76    Fairview  128705.61  2022-01-06
# 3   4       Emma   Martinez   43  Burlington  106198.11  2016-01-05
# 4   5   Benjamin  Rodriguez   62  Manchester  189641.05  2023-04-19
#              id        age         salary
# count  10.00000  10.000000      10.000000
# mean    5.50000  46.900000  103713.770000
# std     3.02765  18.764328   65217.194142
# min     1.00000  21.000000   22669.840000
# 25%     3.25000  31.000000   37387.660000
# 50%     5.50000  46.000000  117451.860000
# 75%     7.75000  60.000000  154446.692500
# max    10.00000  76.000000  189641.050000

# %%
from scipy import stats
data = [1,2,3,4,5,6,8,8,8,8,9,10,10,10,12,14,18,18,18,22,39,44,55,55,55,55,66,78,79,88]
print("\ndes:",stats.describe(data))
print("\ncumfreq:",stats.gmean(data))
print("\n The Geometric mean of the data-n",stats.gmean(data))
print("\n The Harmonic mean of the data-n",stats.hmean(data))
print("\n The IQR of the data-n",stats.iqr(data))
print("\n The Zscore of the data-n",stats.zscore(data))
print("\n The skewness of the data-n",stats.skew(data))
print("\n The Kurtosos of the data-n",stats.kurtosis(data))
# Out:
# des: DescribeResult(nobs=30, minmax=(1, 88), mean=26.933333333333334, variance=715.3057471264368, skewness=0.9591014772240082, kurtosis=-0.5039593211083249)
#
# cumfreq: 15.260661495888634
#
#  The Geometric mean of the data-n 15.260661495888634
#
#  The Harmonic mean of the data-n 7.690170827943984
#
#  The IQR of the data-n 44.25
#
#  The Zscore of the data-n [-0.9862207  -0.94819162 -0.91016255 -0.87213347 -0.8341044  -0.79607532
#  -0.72001717 -0.72001717 -0.72001717 -0.72001717 -0.68198809 -0.64395902
#  -0.64395902 -0.64395902 -0.56790087 -0.49184271 -0.33972641 -0.33972641
#  -0.33972641 -0.18761011  0.45888418  0.64902956  1.06734939  1.06734939
#   1.06734939  1.06734939  1.48566923  1.94201814  1.98004721  2.3223089 ]
#
#  The skewness of the data-n 0.9591014772240082
#
#  The Kurtosos of the data-n -0.5039593211083249

# %%
data = [1,2,3,6,8,10]
data1 = [2,3,4,5,9,12]

print("\n The Spearman correlation of the data-n",stats.spearmanr(data,data1))
# Out:
#  The Spearman correlation of the data-n SignificanceResult(statistic=1.0, pvalue=0.0)

# %%
import pandas as pd
col_list=["id","first_name","last_name","age","city","salary","joined"]
df = pd.read_csv("sample-simple.csv",usecols=col_list)
print(df)
print("end of listing\n\n")
# Out:
#    id first_name  last_name  age        city     salary      joined
# 0   1       Liam   Williams   49   Riverside  156973.24  2020-04-18
# 1   2       Jane   Williams   71    Fairview   50435.05  2024-01-27
# 2   3       Emma      Moore   76    Fairview  128705.61  2022-01-06
# 3   4       Emma   Martinez   43  Burlington  106198.11  2016-01-05
# 4   5   Benjamin  Rodriguez   62  Manchester  189641.05  2023-04-19
# 5   6     Amelia   Williams   34  Manchester   26628.09  2016-08-19
# 6   7        Mia      Jones   21     Ashland   33038.53  2021-01-03
# 7   8       Emma      Lopez   30  Greenville  146867.05  2015-12-15
# 8   9   Isabella      Lopez   29  Greenville  175981.13  2015-01-27
# 9  10     Amelia    Johnson   54     Madison   22669.84  2020-03-09
# end of listing

# %%
# Let us convert the in Gender column, make Female as 0 and 
# male as 1 using LabelEncoder in scikitlearn method

from sklearn.preprocessing import LabelEncoder
df_age_encode=LabelEncoder()
df.age=df_age_encode.fit_transform(df.age)
# One can observe that female is coded as 0 and Male as 1
print(df)
print("End of Listing\n\n\n")
# Out:
#    id first_name  last_name  age        city     salary      joined
# 0   1       Liam   Williams    5   Riverside  156973.24  2020-04-18
# 1   2       Jane   Williams    8    Fairview   50435.05  2024-01-27
# 2   3       Emma      Moore    9    Fairview  128705.61  2022-01-06
# 3   4       Emma   Martinez    4  Burlington  106198.11  2016-01-05
# 4   5   Benjamin  Rodriguez    7  Manchester  189641.05  2023-04-19
# 5   6     Amelia   Williams    3  Manchester   26628.09  2016-08-19
# 6   7        Mia      Jones    0     Ashland   33038.53  2021-01-03
# 7   8       Emma      Lopez    2  Greenville  146867.05  2015-12-15
# 8   9   Isabella      Lopez    1  Greenville  175981.13  2015-01-27
# 9  10     Amelia    Johnson    6     Madison   22669.84  2020-03-09
# End of Listing

# %%
from sklearn import preprocessing
df.salary = preprocessing.scale(df.salary)
scaled_df= preprocessing.scale(df.salary)
print(df)
print("Scaling of marks is completed\n\n\n\n")
# Out:
#    id first_name  last_name  age        city    salary      joined
# 0   1       Liam   Williams    5   Riverside  0.860822  2020-04-18
# 1   2       Jane   Williams    8    Fairview -0.861133  2024-01-27
# 2   3       Emma      Moore    9    Fairview  0.403938  2022-01-06
# 3   4       Emma   Martinez    4  Burlington  0.040154  2016-01-05
# 4   5   Benjamin  Rodriguez    7  Manchester  1.388826  2023-04-19
# 5   6     Amelia   Williams    3  Manchester -1.245921  2016-08-19
# 6   7        Mia      Jones    0     Ashland -1.142310  2021-01-03
# 7   8       Emma      Lopez    2  Greenville  0.697478  2015-12-15
# 8   9   Isabella      Lopez    1  Greenville  1.168043  2015-01-27
# 9  10     Amelia    Johnson    6     Madison -1.309897  2020-03-09
# Scaling of marks is completed

# %%
newarr = scaled_df.reshape(-1,1) 
scaled_df_bin = preprocessing.Binarizer(threshold=0.5).transform(newarr)
df['salary']=scaled_df_bin
print(df)
print("Binarizarion of salary is completed\n\n\n\n")
# Out:
#    id first_name  last_name  age        city  salary      joined
# 0   1       Liam   Williams    5   Riverside     1.0  2020-04-18
# 1   2       Jane   Williams    8    Fairview     0.0  2024-01-27
# 2   3       Emma      Moore    9    Fairview     0.0  2022-01-06
# 3   4       Emma   Martinez    4  Burlington     0.0  2016-01-05
# 4   5   Benjamin  Rodriguez    7  Manchester     1.0  2023-04-19
# 5   6     Amelia   Williams    3  Manchester     0.0  2016-08-19
# 6   7        Mia      Jones    0     Ashland     0.0  2021-01-03
# 7   8       Emma      Lopez    2  Greenville     1.0  2015-12-15
# 8   9   Isabella      Lopez    1  Greenville     1.0  2015-01-27
# 9  10     Amelia    Johnson    6     Madison     0.0  2020-03-09
# Binarizarion of salary is completed

# %%
import pandas as pd
from matplotlib import pyplot as plt

col_list=['NAME','Gender','DOB','Maths','Physics','Chemistry','English','Biology','History','Civics']
df = pd.read_csv('student_marks.csv',usecols=col_list)
print(df)
# Out:
#        NAME Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61
# 7       76      87
# 8       63      89
# 9       46      77

# %%
import pandas as pd
from matplotlib import pyplot as plt

col_list=['NAME','Gender','DOB','Maths','Physics','Chemistry','English','Biology','History','Civics']
df = pd.read_csv('student_marks.csv', usecols=col_list)

# Plot a simple bar chart of names vs math marks
plt.figure(figsize=(10, 5))
plt.bar(df['NAME'], df['Maths'], color='skyblue')
plt.title('Math Marks by Student')
plt.xlabel('Student Name')
plt.ylabel('Marks')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# %pip install --force-reinstall matplotlib pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp310-cp310-win_amd64.whl.metadata (52 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp310-cp310-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp310-cp310-win_amd64.whl.metadata (5.2 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting packaging>=20.0 (from matplotlib)
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.3.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.10.9-cp310-cp310-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -------------- ------------------------- 2.9/8.2 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 28.1 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------------------------------ --- 10.5/11.3 MB 46.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 41.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp310-cp310-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 42.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp310-cp310-win_amd64.whl (73 kB)
# Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------------------------------- ------- 10.5/12.9 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 47.5 MB/s eta 0:00:00
# Using cached packaging-26.2-py3-none-any.whl (100 kB)
# Downloading pillow-12.3.0-cp310-cp310-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 44.6 MB/s eta 0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, six, pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, cycler, python-dateutil, contourpy, pandas, matplotlib
#
#    ----------------------------------------  0/14 [pytz]
#    -- -------------------------------------  1/14 [tzdata]
#    -- -------------------------------------  1/14 [tzdata]
#    -------- -------------------------------  3/14 [pyparsing]
#    ----------- ----------------------------  4/14 [pillow]
#    ----------- ----------------------------  4/14 [pillow]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ----------------- ----------------------  6/14 [numpy]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------- -----------------  8/14 [fonttools]
#    ---------------------------- ----------- 10/14 [python-dateutil]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ---------------------------------- ----- 12/14 [pandas]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ------------------------------------- -- 13/14 [matplotlib]
#    ---------------------------------------- 14/14 [matplotlib]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.2.6 packaging-26.2 pandas-2.3.3 pillow-12.3.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 pytz-2026.2 six-1.17.0 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\student\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\student\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.10.0 requires libclang>=13.0.0, which is not installed.
# tensorflow 2.10.0 requires tensorflow-io-gcs-filesystem>=0.23.1, which is not installed.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.

# %%
marks_scored = df['Physics'].hist()
plt.title('Histogram for Physics Marks')
plt.xlabel('Physics Marks')
plt.ylabel('Frequency of Physics Marks')
plt.show()

# %%
chemistry1 = df['Chemistry'].values.tolist()
print (chemistry1)
# Out:
# [56, 78, 89, 86, 78, 52, 61, 87, 89, 77]

# %%
marks1 = df['Physics'].values.tolist()
plt.scatter(chemistry1,marks1,alpha=0.5)
plt.title('Scatter plot chemistry vs physics')
plt.xlabel('Chemistry')
plt.ylabel('Physics')
plt.show()

# %%
df.plot.box(title="Box and whisker plot of Marks", grid=False)
plt.show(block=True)

# %%
df.plot(kind='box',subplots=True,layout=(3,3),sharex=False,sharey=False)
# Out:
# Maths           Axes(0.125,0.653529;0.227941x0.226471)
# Physics      Axes(0.398529,0.653529;0.227941x0.226471)
# Chemistry    Axes(0.672059,0.653529;0.227941x0.226471)
# English         Axes(0.125,0.381765;0.227941x0.226471)
# Biology      Axes(0.398529,0.381765;0.227941x0.226471)
# History      Axes(0.672059,0.381765;0.227941x0.226471)
# Civics              Axes(0.125,0.11;0.227941x0.226471)
# dtype: object

# %%
cols=df[['NAME','Gender','Biology']]
df2 = df.drop(cols, axis=1)
pd.plotting.scatter_matrix(df2, alpha=0.2)
plt.show()

# %%
import pandas as pd

df = pd.read_csv("iris.csv")
data = df.iloc[1:20]


data.plot.scatter('sepal.length','sepal.width')

data.hist(column='variety',by='variety') 
data.boxplot(column='sepal.length',by='variety')
# Out:
# <Axes: title={'center': 'sepal.length'}, xlabel='variety'>

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# Create a synthetic dataset

data = {'week': [1,2,3,4,5],
        'sales':[1.2,1.8,2.6,3.2,3.8],            
        'region':['south','south','north','north','north']
       }

df = pd.DataFrame(data)

# Read the preloaded dataset Iris using data frame 1 - df1

df1 = sns.load_dataset('iris')

sns.set(color_codes=True)

### Univariate Plots

# Histogram plot using barplot

print("\nHistogram of week vs Sales\n")
sns.barplot(x = "week", y = "sales", hue = "region", data = df) 
plt.show()
# Out:
# Histogram of week vs Sales

# %%
# Box Plot

print("\nBox Plot of week and sales data\n")
sns.boxplot(data=df)
plt.xlabel("Statistics", size=18)
plt.ylabel("Week and Sales Data", size=18)
plt.show()

# Distplot - Distribution plots

# Display the histogram by making kde flag as falsse
sns.distplot(df1['sepal_width'],kde = False).set_title('Distribution plot for sepal_width')
plt.xlabel("Sepal Width", size=18)
plt.ylabel("Frequency", size=18)
plt.show()

# Display the Distribution plot by making hist flag as false 
sns.distplot(df1['sepal_width'],hist = False).set_title('Distribution plot for sepal_width')
plt.xlabel("Sepal Width", size=18)
plt.ylabel("Frequency", size=18)
plt.show()

# Violin Plot

print("\n Violin Plot of week and sales data\n")
sns.violinplot(data = df).set_title('Violin Plot for week and sales data')
plt.xlabel("Statistics", size=18)
plt.ylabel("Region", size=18)
plt.show()

# Count Plot for Iris Data
# Out:
# Box Plot of week and sales data
# C:\Users\student\AppData\Local\Temp\ipykernel_17932\57481214.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['sepal_width'],kde = False).set_title('Distribution plot for sepal_width')
# C:\Users\student\AppData\Local\Temp\ipykernel_17932\57481214.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['sepal_width'],hist = False).set_title('Distribution plot for sepal_width')
#  Violin Plot of week and sales data

# %%
sns.countplot(x = "region", data = df, palette = "Blues").set_title('Count plot Based on regions')
plt.xlabel("Statistics", size=18)
plt.ylabel("Region", size=18)
plt.show()

            
# Strip plot for Iris Data
print('\n Strip plot\n')
sns.stripplot(x = "species", y = "petal_length", data = df1).set_title('Strip plot for petal length and class')
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_17932\3936394242.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "region", data = df, palette = "Blues").set_title('Count plot Based on regions')
#  Strip plot
# Text(0.5, 1.0, 'Strip plot for petal length and class')

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# Create a synthetic dataset
data = {'week': [1,2,3,4,5],
        'sales':[1.2,1.8,2.6,3.2,3.8],            
        'region':['south','south','north','north','north']
       }

df = pd.DataFrame(data)

# Read the preloaded dataset Iris using data frame 1 - df1

df1 = sns.load_dataset('iris')

sns.set(color_codes=True)

### Bivariate Plots

# Joint Plot
print('\n Joint Plot of week and sales\n')
sns.jointplot(x = 'week',y = 'sales',data = df)
plt.show()

#lmplot

print('\n lmplot of week and sales Based on Region\n\n')
g1 = sns.lmplot(x="week", y="sales", hue="region", data=df)

### Multivariate Plots

# pairplot
sns.pairplot(df1,hue = 'species',kind = "scatter") 
plt.show()
# Out:
#  Joint Plot of week and sales
#  lmplot of week and sales Based on Region

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import ttest_ind

# Perform Chisquare Test

# Compute the Observed value

table = [ [35,15],
          [25,25]
          ]
print('\n Obervartion Table')
# Print the observed value
print(table)

#Perform the Chi square test
stat,p,dof,expected = chi2_contingency(table)

# Compute the expected value
print('\n')
print('\n Expectation Table')
print(expected)

# Set the parameters
prob = 0.90

# Find the critical value
critical = chi2.ppf(prob,dof)
# Print the critical value
print('\n')
print('The critical Value')
print(critical)

print('statistical value')
print(stat)

if abs(stat) >= critical:
    print('Stat value greater or equal to critical:Reject Null Hypotheis')
else:
    print('Stat value is less than critical: Accept Alt Hypothesis')

# Perform t-Tests

x = ([6,3,4,5,5,9,7,8])
y = ([4,4,1,3,5,6,2,7])
print('\n')
print('Statistical value')
print(stat)
print('p value')
print(p)


print('\n')
print('t-Test completed\n\n')
stat,p= ttest_ind(x,y,equal_var=True)
# Out:
#  Obervartion Table
# [[35, 15], [25, 25]]
#
#
#
#  Expectation Table
# [[30. 20.]
#  [30. 20.]]
#
#
# The critical Value
# 2.705543454095404
# statistical value
# 3.375
# Stat value greater or equal to critical:Reject Null Hypotheis
#
#
# Statistical value
# 3.375
# p value
# 0.06619257972219346
#
#
# t-Test completed

# %%
import math
import numpy as np
x = np.linspace(-np.pi,np.pi,100)
y=np.sin(x)
plt.plot(x,y)

# %%
from numpy import linalg
x = np.array([[1,2],[2,3]])
y = np.array([4,5,6,7])
det1 = np.linalg.det(x)
print(det1)
# Out:
# -1.0

# %%
x=[1,2,3]
y=[5,10,15]

plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Line Graph")
plt.show()

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.lineplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(data = df,palette="Greens")
# Out:
# <Axes: >

# %%
x= np.linspace(0,1,10)
y=x**2
plt.plot(x,y)
