# %%
from sklearn import linear_model
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression


X,y = make_regression(n_samples = 50,n_features=1,noise=0.1)



regr = linear_model.LinearRegression()
regr.fit(X,y)

print('Intercept: \n', regr.intercept_)
print('Coefficients:\n', regr.coef_)

print('\nScore of Linear Regression:')
print(regr.score(X,y))



clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X, y)
clf.fit(X,y)
print('\nRidge Regression\n')
print('Ridge Intercept:', clf.intercept_)
print('Ridge Coefficients:', clf.coef_)
print('\nScore of Ridge Regression:')
print(clf.score(X,y))

print("\nAdjusted R Squared for Ridge Regression mdel:",clf.score(X,y))



clf1 = linear_model.Lasso(alpha=0.1).fit(X,y)
print('\nLasso Regression\n')
print('Lasso Intercept:', clf1.intercept_)
print('Lasso Coefficients:', clf1.coef_)
print('\nScore of Lasso Regression:')
print(clf1.score(X,y))

print("\nAdjusted R Squared for Lasso Regression mdel:",clf1.score(X,y))



clf2 =ElasticNet(random_state=0).fit(X,y)
print('\nElasticNet Regression\n')
print('ElasticNet Intercept:', clf2.intercept_)
print('ElasticNet Coefficients:', clf2.coef_)
print('\nScore of ElasticNet Regression:')

print(clf2.score(X,y))

print("\nAdjusted R Squared for ElasticNet Regression mdel:",clf2.score(X,y))
# Out:
# Intercept:
#  0.008300809570159995
# Coefficients:
#  [52.50599652]
#
# Score of Linear Regression:
# 0.9999954175266554
#
# Ridge Regression
#
# Ridge Intercept: 0.008335311056739458
# Ridge Coefficients: [52.50419417]
#
# Score of Ridge Regression:
# 0.9999954163483475
#
# Adjusted R Squared for Ridge Regression mdel: 0.9999954163483475
#
# Lasso Regression
#
# Lasso Intercept: 0.011586402562759668
# Lasso Coefficients: [52.3343578]
#
# Score of Lasso Regression:
# 0.9999847316361621
#
# Adjusted R Squared for Lasso Regression mdel: 0.9999847316361621
#
# ElasticNet Regression
#
# ElasticNet Intercept: 0.48133797998678207
# ElasticNet Coefficients: [27.79462986]
#
# Score of ElasticNet Regression:
# 0.7784954186037993
#
# Adjusted R Squared for ElasticNet Regression mdel: 0.7784954186037993

# %%
import pandas as pd 
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error, mean_absolute_error
X, y = make_blobs(n_samples=200, centers=3, n_features=3)
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
# Print the sample top five records
print("Top five Records\n\n")
df_top = df.head(5) 
print(df_top)
 # Condition the input
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.40,random_state=0)
# Construct the logistic regression model
model = LogisticRegression()
# Fit the model
model.fit(X_train,y_train) 
#Prediction for the test sample
predicted = model.predict(X_test)
# Print the classification report
print("\n\nClassification Report")
report_lr = classification_report(y_test,predicted)
print(report_lr)
clf2 = ElasticNet(
    alpha=0.1,
    random_state=0
)
clf2.fit(X, y)
y_pred_elastic = clf2.predict(X)
print("MSE:", mean_squared_error(y, y_pred_elastic))
print("MAE:", mean_absolute_error(y, y_pred_elastic))
# Out:
# Top five Records
#
#
#           x         y  label
# 0 -1.022061 -3.281609      2
# 1 -1.939262 -1.856604      2
# 2 -1.259704 -2.164365      2
# 3 -6.408867  2.453762      1
# 4  0.192528 -1.911799      2
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        25
#            2       1.00      1.00      1.00        26
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
#
# MSE: 0.05828690530914648
# MAE: 0.18885382578684656

# %%
regr = linear_model.LinearRegression()
regr.fit(X,y)

print('Intercept: \n', regr.intercept_)
print('Coefficients:\n', regr.coef_)

print('\nScore of Linear Regression:')
print(regr.score(X,y))
# Out:
# Intercept:
#  -0.00045101193837027154
# Coefficients:
#  [72.59831295]
#
# Score of Linear Regression:
# 0.9999978974056254

# %%
clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X, y)
clf.fit(X,y)
print('\nRidge Regression\n')
print('Ridge Intercept:', clf.intercept_)
print('Ridge Coefficients:', clf.coef_)
print('\nScore of Ridge Regression:')
print(clf.score(X,y))

print("\nAdjusted R Squared for Ridge Regression mdel:",clf.score(X,y))
# Out:
# Ridge Regression
#
# Ridge Intercept: -0.0007971895677236773
# Ridge Coefficients: [72.59631449]
#
# Score of Ridge Regression:
# 0.999997896647859
#
# Adjusted R Squared for Ridge Regression mdel: 0.999997896647859

# %%
clf1 = linear_model.Lasso(alpha=0.1).fit(X,y)
print('\nLasso Regression\n')
print('Lasso Intercept:', clf1.intercept_)
print('Lasso Coefficients:', clf1.coef_)
print('\nScore of Lasso Regression:')
print(clf1.score(X,y))

print("\nAdjusted R Squared for Lasso Regression mdel:",clf1.score(X,y))
# Out:
# Lasso Regression
#
# Lasso Intercept: -0.024293658298770282
# Lasso Coefficients: [72.46067122]
#
# Score of Lasso Regression:
# 0.9999943028413868
#
# Adjusted R Squared for Lasso Regression mdel: 0.9999943028413868

# %%
clf2 =ElasticNet(random_state=0).fit(X,y)
print('\nElasticNet Regression\n')
print('ElasticNet Intercept:', clf2.intercept_)
print('ElasticNet Coefficients:', clf2.coef_)
print('\nScore of ElasticNet Regression:')

print(clf2.score(X,y))

print("\nAdjusted R Squared for ElasticNet Regression mdel:",clf2.score(X,y))
# Out:
# ElasticNet Regression
#
# ElasticNet Intercept: -5.197612421103413
# ElasticNet Coefficients: [42.59550807]
#
# Score of ElasticNet Regression:
# 0.829205024149452
#
# Adjusted R Squared for ElasticNet Regression mdel: 0.829205024149452

# %%
from sklearn import linear_model
linear_model.LinearRegression()
linear_model.Lasso()
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
X,y = make_regression(
    n_samples=50,
    n_features=1,
    noise= 0.1  
)
regr= linear_model.LinearRegression()
regr.fit(X,y)
print('Intercept: \n', regr.intercept_)
print('Coefficients:\n', regr.coef_)
print(regr.score(X,y))
clf = RidgeCV(
    alphas=[1e-3, 1e-2, 1e-1, 1]
).fit(X, y)

print('Ridge Intercept:',clf.intercept_)
print('Ridge Coefficients:',clf.coef_)
print(clf.score(X,y))
print(
    "\nAdjusted R Squared for Ridge Regression mdel:",
    clf.score(X,y)
)
clf1 = linear_model.Lasso(alpha=0.1).fit(X,y)
print('Lasso Intercept:', clf1.intercept_)
print('Lasso Coefficients:', clf1.coef_)
print(clf1.score(X,y))
clf2 = ElasticNet(random_state=0).fit(X,y)
print(
    'ElasticNet Intercept:',
    clf2.intercept_
)
print(
    'ElasticNet Coefficients:',
    clf2.coef_
)
print(clf2.score(X,y))
# Out:
# Intercept:
#  -0.0058017958035936346
# Coefficients:
#  [60.88858318]
# 0.9999960017941733
# Ridge Intercept: -0.005726014032864324
# Ridge Coefficients: [60.88718822]
# 0.9999960012693074
#
# Adjusted R Squared for Ridge Regression mdel: 0.9999960012693074
# Lasso Intercept: 0.0004213357770765924
# Lasso Coefficients: [60.77403054]
# 0.9999924623363631
# ElasticNet Intercept: 1.218606287667117
# ElasticNet Coefficients: [38.3502232]
# 0.8629800446847491

# %%
from sklearn.metrics import mean_squared_error

y_pred = clf2.predict(X)

mse = mean_squared_error(y, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 443.45768787566055

# %%
from sklearn.metrics import mean_absolute_error

y_pred = clf2.predict(X)

mae = mean_absolute_error(y, y_pred)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 16.80598691306637
